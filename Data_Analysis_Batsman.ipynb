# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\user\\Documents'

# %%
# import & setup
import numpy as np
import pandas as pd
# Load Data from CSV
df = pd.read_csv("Batsman.csv")      
print(df)
# Out:
#      RunsScored  BallsFaced  BattingPosition Dismissal  Inning   Opposition  \
# 0            12          22                2       LBW       1    Sri Lanka
# 1            37          67                2    Caught       2    Sri Lanka
# 2            25          38                1   Run out       1    Sri Lanka
# 3            54          66                1    Bowled       1    Sri Lanka
# 4            31          46                1       LBW       2    Sri Lanka
# ..          ...         ...              ...       ...     ...          ...
# 203         140         107                3   Stumped       2  West Indies
# 204         157         129                3        NO       1  West Indies
# 205         107         119                3    Bowled       2  West Indies
# 206          16          17                3    Caught       1  West Indies
# 207          33          29                3        NO       2  West Indies
#
#      Year
# 0    2008
# 1    2008
# 2    2008
# ...

# %%
# Inspect Data
df.head()
# Out:
#    RunsScored  BallsFaced  BattingPosition Dismissal  Inning Opposition  Year
# 0          12          22                2       LBW       1  Sri Lanka  2008
# 1          37          67                2    Caught       2  Sri Lanka  2008
# 2          25          38                1   Run out       1  Sri Lanka  2008
# 3          54          66                1    Bowled       1  Sri Lanka  2008
# 4          31          46                1       LBW       2  Sri Lanka  2008

# %%
df.tail()
# Out:
#      RunsScored  BallsFaced  BattingPosition Dismissal  Inning   Opposition  \
# 203         140         107                3   Stumped       2  West Indies
# 204         157         129                3        NO       1  West Indies
# 205         107         119                3    Bowled       2  West Indies
# 206          16          17                3    Caught       1  West Indies
# 207          33          29                3        NO       2  West Indies
#
#      Year
# 203  2018
# 204  2018
# 205  2018
# 206  2018
# 207  2018

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RunsScored       208 non-null    int64
#  1   BallsFaced       208 non-null    int64
#  2   BattingPosition  208 non-null    int64
#  3   Dismissal        208 non-null    object
#  4   Inning           208 non-null    int64
#  5   Opposition       208 non-null    object
#  6   Year             208 non-null    int64
# dtypes: int64(5), object(2)
# memory usage: 11.5+ KB

# %%
df.dtypes
# Out:
# RunsScored          int64
# BallsFaced          int64
# BattingPosition     int64
# Dismissal          object
# Inning              int64
# Opposition         object
# Year                int64
# dtype: object

# %%
df.shape
# Out:
# (208, 7)

# %%
df.columns
# Out:
# Index(['RunsScored', 'BallsFaced', 'BattingPosition', 'Dismissal', 'Inning',
#        'Opposition', 'Year'],
#       dtype='object')

# %%
df.describe()
# Out:
#        RunsScored  BallsFaced  BattingPosition      Inning         Year
# count  208.000000  208.000000       208.000000  208.000000   208.000000
# mean    49.192308   52.961538         3.264423    1.567308  2013.240385
# std     43.797641   39.850548         0.781602    0.496644     2.750477
# min      0.000000    0.000000         1.000000    1.000000  2008.000000
# 25%     10.750000   18.000000         3.000000    1.000000  2011.000000
# 50%     35.000000   46.500000         3.000000    2.000000  2013.000000
# 75%     81.250000   83.250000         3.000000    2.000000  2015.000000
# max    183.000000  159.000000         7.000000    2.000000  2018.000000

# %%
df.head(5)
# Out:
#    RunsScored  BallsFaced  BattingPosition Dismissal  Inning Opposition  Year
# 0          12          22                2       LBW       1  Sri Lanka  2008
# 1          37          67                2    Caught       2  Sri Lanka  2008
# 2          25          38                1   Run out       1  Sri Lanka  2008
# 3          54          66                1    Bowled       1  Sri Lanka  2008
# 4          31          46                1       LBW       2  Sri Lanka  2008

# %%
df.describe(include="all")
# Out:
#         RunsScored  BallsFaced  BattingPosition Dismissal      Inning  \
# count   208.000000  208.000000       208.000000       208  208.000000
# unique         NaN         NaN              NaN         7         NaN
# top            NaN         NaN              NaN    Caught         NaN
# freq           NaN         NaN              NaN       121         NaN
# mean     49.192308   52.961538         3.264423       NaN    1.567308
# std      43.797641   39.850548         0.781602       NaN    0.496644
# min       0.000000    0.000000         1.000000       NaN    1.000000
# 25%      10.750000   18.000000         3.000000       NaN    1.000000
# 50%      35.000000   46.500000         3.000000       NaN    2.000000
# 75%      81.250000   83.250000         3.000000       NaN    2.000000
# max     183.000000  159.000000         7.000000       NaN    2.000000
#
#        Opposition         Year
# count         208   208.000000
# unique         12          NaN
# ...

# %%
df.min()
# Out:
# RunsScored                 0
# BallsFaced                 0
# BattingPosition            1
# Dismissal             Bowled
# Inning                     1
# Opposition         Australia
# Year                    2008
# dtype: object

# %%
df.max()
# Out:
# RunsScored              183
# BallsFaced              159
# BattingPosition           7
# Dismissal           Stumped
# Inning                    2
# Opposition         Zimbabwe
# Year                   2018
# dtype: object

# %%
df.count()
# Out:
# RunsScored         208
# BallsFaced         208
# BattingPosition    208
# Dismissal          208
# Inning             208
# Opposition         208
# Year               208
# dtype: int64

# %%
# select & filter data
df['RunsScored']
# Out:
# 0       12
# 1       37
# 2       25
# 3       54
# 4       31
#       ...
# 203    140
# 204    157
# 205    107
# 206     16
# 207     33
# Name: RunsScored, Length: 208, dtype: int64

# %%
df[['RunsScored','Opposition']]
# Out:
#      RunsScored   Opposition
# 0            12    Sri Lanka
# 1            37    Sri Lanka
# 2            25    Sri Lanka
# 3            54    Sri Lanka
# 4            31    Sri Lanka
# ..          ...          ...
# 203         140  West Indies
# 204         157  West Indies
# 205         107  West Indies
# 206          16  West Indies
# 207          33  West Indies
#
# [208 rows x 2 columns]

# %%
df[['Year','RunsScored']]
# Out:
#      Year  RunsScored
# 0    2008          12
# 1    2008          37
# 2    2008          25
# 3    2008          54
# 4    2008          31
# ..    ...         ...
# 203  2018         140
# 204  2018         157
# 205  2018         107
# 206  2018          16
# 207  2018          33
#
# [208 rows x 2 columns]

# %%
df['Year']
# Out:
# 0      2008
# 1      2008
# 2      2008
# 3      2008
# 4      2008
#        ...
# 203    2018
# 204    2018
# 205    2018
# 206    2018
# 207    2018
# Name: Year, Length: 208, dtype: int64

# %%
df['Strike_Rate']=df['RunsScored']/df['BallsFaced']

# %%
df.head()
# Out:
#    RunsScored  BallsFaced  BattingPosition Dismissal  Inning Opposition  Year  \
# 0          12          22                2       LBW       1  Sri Lanka  2008
# 1          37          67                2    Caught       2  Sri Lanka  2008
# 2          25          38                1   Run out       1  Sri Lanka  2008
# 3          54          66                1    Bowled       1  Sri Lanka  2008
# 4          31          46                1       LBW       2  Sri Lanka  2008
#
#    Strike_Rate
# 0     0.545455
# 1     0.552239
# 2     0.657895
# 3     0.818182
# 4     0.673913

# %%
# to get minimum value
min_Score = df['RunsScored'].min()
print(min_Score)
# Out:
# 0

# %%
# max value
max_Score = df['RunsScored'].max()
print(max_Score)
# Out:
# 183

# %%
import numpy as np
import pandas as pd
df = pd.read_csv("Batsman.csv")
df_max_Score= df['RunsScored'].max()
print(df_max_Score)
# Out:
# 183

# %%
numerical_col=df.select_dtypes(include=['int64','float64'])
print(numerical_col)
categorical_col=df.select_dtypes(include=['object'])
print(categorical_col)
# Out:
#      RunsScored  BallsFaced  BattingPosition  Inning  Year
# 0            12          22                2       1  2008
# 1            37          67                2       2  2008
# 2            25          38                1       1  2008
# 3            54          66                1       1  2008
# 4            31          46                1       2  2008
# ..          ...         ...              ...     ...   ...
# 203         140         107                3       2  2018
# 204         157         129                3       1  2018
# 205         107         119                3       2  2018
# 206          16          17                3       1  2018
# 207          33          29                3       2  2018
#
# [208 rows x 5 columns]
#     Dismissal   Opposition
# 0         LBW    Sri Lanka
# 1      Caught    Sri Lanka
# 2     Run out    Sri Lanka
# 3      Bowled    Sri Lanka
# 4         LBW    Sri Lanka
# ..        ...          ...
# 203   Stumped  West Indies
# ...

# %%
df['Run_category']=np.where(df['RunsScored']<=50,"low",np.where(df['RunsScored']<=100,"Medium","High"))
df.head(30)
# Out:
#     RunsScored  BallsFaced  BattingPosition Dismissal  Inning    Opposition  \
# 0           12          22                2       LBW       1     Sri Lanka
# 1           37          67                2    Caught       2     Sri Lanka
# 2           25          38                1   Run out       1     Sri Lanka
# 3           54          66                1    Bowled       1     Sri Lanka
# 4           31          46                1       LBW       2     Sri Lanka
# 5            2           2                7        NO       1     Sri Lanka
# 6           16          24                4    Caught       2      Pakistan
# 7           79         104                4        NO       2   West Indies
# 8           30          41                4    Caught       2     Australia
# 9           10          16                3    Caught       2     Australia
# 10          27          19                7    Bowled       1     Sri Lanka
# ...

# %%
# unique values per column
df['Opposition'].unique()
# Out:
# array(['Sri Lanka', 'Pakistan', 'West Indies', 'Australia', 'Bangladesh',
#        'South Africa', 'Zimbabwe', 'New Zealand', 'England', 'Ireland',
#        'Netherlands', 'U.A.E.'], dtype=object)

# %%
df['Opposition'].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0        Sri Lanka
# 1        Sri Lanka
# 2        Sri Lanka
# 3        Sri Lanka
# 4        Sri Lanka
#           ...
# 203    West Indies
# 204    West Indies
# 205    West Indies
# 206    West Indies
# 207    West Indies
# Name: Opposition, Length: 208, dtype: object>

# %%
# frequency count
df['Opposition'].value_counts()
# Out:
# Opposition
# Sri Lanka       45
# West Indies     32
# England         29
# Australia       26
# South Africa    24
# New Zealand     19
# Pakistan        12
# Bangladesh      11
# Zimbabwe         6
# Ireland          2
# Netherlands      1
# U.A.E.           1
# Name: count, dtype: int64

# %%
df.sort_values(by='RunsScored')
# Out:
#      RunsScored  BallsFaced  BattingPosition Dismissal  Inning    Opposition  \
# 28            0           3                3    Caught       2     Sri Lanka
# 53            0           1                3       LBW       2   West Indies
# 87            0           5                3    Bowled       1      Pakistan
# 94            0           1                3    Caught       1       England
# 126           0           3                3    Caught       1       England
# ..          ...         ...              ...       ...     ...           ...
# 203         140         107                3   Stumped       2   West Indies
# 165         154         134                3        NO       2   New Zealand
# 204         157         129                3        NO       1   West Indies
# 196         160         159                3        NO       1  South Africa
# 81          183         148                3    Caught       2      Pakistan
#
#      Year Run_category
# ...

# %%
df.sort_values(by='RunsScored',ascending=False)
# Out:
#      RunsScored  BallsFaced  BattingPosition Dismissal  Inning    Opposition  \
# 81          183         148                3    Caught       2      Pakistan
# 196         160         159                3        NO       1  South Africa
# 204         157         129                3        NO       1   West Indies
# 165         154         134                3        NO       2   New Zealand
# 203         140         107                3   Stumped       2   West Indies
# ..          ...         ...              ...       ...     ...           ...
# 117           0           5                3    Caught       2  South Africa
# 20            0           0                3   Run out       1      Zimbabwe
# 126           0           3                3    Caught       1       England
# 65            0           5                3    Bowled       1       England
# 186           0           4                3    Caught       1     Australia
#
#      Year Run_category
# ...

# %%
my_dict={"Name":["andrew","bobby","charlie","david"],
         "Age":[30,25,40,28],
        "Department":["hx","admin","sales","IT"]
        }
print(my_dict)
# Out:
# {'Name': ['andrew', 'bobby', 'charlie', 'david'], 'Age': [30, 25, 40, 28], 'Department': ['hx', 'admin', 'sales', 'IT']}

# %%
df=pd.DataFrame(my_dict)
print(df)
# Out:
#       Name  Age Department
# 0   andrew   30         hx
# 1    bobby   25      admin
# 2  charlie   40      sales
# 3    david   28         IT

# %%
my_dict={"Name":["andrew","bobby","charlie","david"],
         "Age":[30,25,40,28],
        "Department":["hx","admin","sales","IT"]
        }
import pandas as pd
df=pd.DataFrame(my_dict)
print(df)
# Out:
#       Name  Age Department
# 0   andrew   30         hx
# 1    bobby   25      admin
# 2  charlie   40      sales
# 3    david   28         IT

# %%
df1={"ID":[1,2,3,4,5],
     "Name":["a","b","c","d","e"],
     "City":["chennai","banglore","hyderabad","delhi","mumbai"]
    }
import pandas as pd
df1=pd.DataFrame(df1)
print(df1)
# Out:
#    ID Name       City
# 0   1    a    chennai
# 1   2    b   banglore
# 2   3    c  hyderabad
# 3   4    d      delhi
# 4   5    e     mumbai

# %%
df2={"ID":[1,2,3],
     "Deptid":[10,20,30],
     "Deptname":["admin","IT","engineer"]
    }
import pandas as pd
df2=pd.DataFrame(df2)
print(df2)
# Out:
#    ID  Deptid  Deptname
# 0   1      10     admin
# 1   2      20        IT
# 2   3      30  engineer

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # df1 and df2 are merge the new_data

# %%
new_data=pd.merge(df1,df2,on="ID")
print(new_data)
# Out:
#    ID Name       City  Deptid  Deptname
# 0   1    a    chennai      10     admin
# 1   2    b   banglore      20        IT
# 2   3    c  hyderabad      30  engineer

# %%
new_data=pd.merge(df1,df2,on="ID",how="inner")
print(new_data)
# Out:
#    ID Name       City  Deptid  Deptname
# 0   1    a    chennai      10     admin
# 1   2    b   banglore      20        IT
# 2   3    c  hyderabad      30  engineer

# %%
new_data=pd.merge(df1,df2,on="ID",how="left")
print(new_data)
# Out:
#    ID Name       City  Deptid  Deptname
# 0   1    a    chennai    10.0     admin
# 1   2    b   banglore    20.0        IT
# 2   3    c  hyderabad    30.0  engineer
# 3   4    d      delhi     NaN       NaN
# 4   5    e     mumbai     NaN       NaN

# %%
new_data=pd.merge(df1,df2,on="ID",how="right")
print(new_data)
# Out:
#    ID Name       City  Deptid  Deptname
# 0   1    a    chennai      10     admin
# 1   2    b   banglore      20        IT
# 2   3    c  hyderabad      30  engineer

# %%
new_data=pd.merge(df1,df2,on="ID",how="outer")
print(new_data)
# Out:
#    ID Name       City  Deptid  Deptname
# 0   1    a    chennai    10.0     admin
# 1   2    b   banglore    20.0        IT
# 2   3    c  hyderabad    30.0  engineer
# 3   4    d      delhi     NaN       NaN
# 4   5    e     mumbai     NaN       NaN

# %%
new_data=pd.merge(df1,df2,how="cross")
print(new_data)
# Out:
#     ID_x Name       City  ID_y  Deptid  Deptname
# 0      1    a    chennai     1      10     admin
# 1      1    a    chennai     2      20        IT
# 2      1    a    chennai     3      30  engineer
# 3      2    b   banglore     1      10     admin
# 4      2    b   banglore     2      20        IT
# 5      2    b   banglore     3      30  engineer
# 6      3    c  hyderabad     1      10     admin
# 7      3    c  hyderabad     2      20        IT
# 8      3    c  hyderabad     3      30  engineer
# 9      4    d      delhi     1      10     admin
# 10     4    d      delhi     2      20        IT
# 11     4    d      delhi     3      30  engineer
# 12     5    e     mumbai     1      10     admin
# 13     5    e     mumbai     2      20        IT
# 14     5    e     mumbai     3      30  engineer

# %%
# common operation-replace()
data=pd.DataFrame({"Name":["A","B","C","D"],"Age":[10,20,30,40]})
print(data)
data=data.replace("D","E")
print(data)
# Out:
#   Name  Age
# 0    A   10
# 1    B   20
# 2    C   30
# 3    D   40
#   Name  Age
# 0    A   10
# 1    B   20
# 2    C   30
# 3    E   40

# %%
# rename()
data=pd.DataFrame({"Name":["A","B","C","D"],"Age":[10,20,30,40]})
data=data.rename(columns={"Name":"Full_name"})
print(data)
# Out:
#   Full_name  Age
# 0         A   10
# 1         B   20
# 2         C   30
# 3         D   40

# %%
import pandas as pd
import numpy as np
data={"Name":["A","B","C"],"Marks":[20,"?",40]}
df=pd.DataFrame(data)
print(df.dtypes)
# Out:
# Name     object
# Marks    object
# dtype: object

# %%
import pandas as pd
import numpy as np
data={"Name":["A","B","C"],"Marks":[20,"?",40]}
df=pd.DataFrame(data)
print(df.dtypes)
df1=data["Marks"]
print(df1)
# Out:
# Name     object
# Marks    object
# dtype: object
# [20, '?', 40]

# %%
pd.to_numeric(data["Marks"],errors='coerce')
# Out:
# array([20., nan, 40.])

# %%
import numpy as np
import pandas as pd
df = pd.read_csv("Batsman.csv")
print(df)
# Out:
#      RunsScored  BallsFaced  BattingPosition Dismissal  Inning   Opposition  \
# 0            12          22                2       LBW       1    Sri Lanka
# 1            37          67                2    Caught       2    Sri Lanka
# 2            25          38                1   Run out       1    Sri Lanka
# 3            54          66                1    Bowled       1    Sri Lanka
# 4            31          46                1       LBW       2    Sri Lanka
# ..          ...         ...              ...       ...     ...          ...
# 203         140         107                3   Stumped       2  West Indies
# 204         157         129                3        NO       1  West Indies
# 205         107         119                3    Bowled       2  West Indies
# 206          16          17                3    Caught       1  West Indies
# 207          33          29                3        NO       2  West Indies
#
#      Year
# 0    2008
# 1    2008
# 2    2008
# ...

# %%
# grouping & aggregation
df.groupby("Opposition")["RunsScored"].mean()
# Out:
# Opposition
# Australia       45.461538
# Bangladesh      59.454545
# England         38.344828
# Ireland         39.000000
# Netherlands     12.000000
# New Zealand     60.736842
# Pakistan        38.250000
# South Africa    52.875000
# Sri Lanka       48.577778
# U.A.E.          33.000000
# West Indies     57.500000
# Zimbabwe        42.166667
# Name: RunsScored, dtype: float64

# %%
df.groupby("Opposition")["BallsFaced"].max()
# Out:
# Opposition
# Australia       121
# Bangladesh      122
# England         105
# Ireland          53
# Netherlands      20
# New Zealand     134
# Pakistan        148
# South Africa    159
# Sri Lanka       126
# U.A.E.           41
# West Indies     129
# Zimbabwe        108
# Name: BallsFaced, dtype: int64

# %%
df.isnull()
# Out:
#      RunsScored  BallsFaced  BattingPosition  Dismissal  Inning  Opposition  \
# 0         False       False            False      False   False       False
# 1         False       False            False      False   False       False
# 2         False       False            False      False   False       False
# 3         False       False            False      False   False       False
# 4         False       False            False      False   False       False
# ..          ...         ...              ...        ...     ...         ...
# 203       False       False            False      False   False       False
# 204       False       False            False      False   False       False
# 205       False       False            False      False   False       False
# 206       False       False            False      False   False       False
# 207       False       False            False      False   False       False
#
#       Year
# 0    False
# 1    False
# 2    False
# ...

# %%
df.isnull().sum()
# Out:
# RunsScored         0
# BallsFaced         0
# BattingPosition    0
# Dismissal          0
# Inning             0
# Opposition         0
# Year               0
# dtype: int64

# %%
df["RunsScored"].median()
# Out:
# 35.0

# %%
df["RunsScored"].mean()
# Out:
# np.float64(49.19230769230769)

# %%
df["RunsScored"].mode()
# Out:
# 0    0
# Name: RunsScored, dtype: int64

# %% [markdown]
# ## DATA VISUALIZATION

# %% [markdown]
# # UNI-VARIATE

# %%
# 1) Histogram


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dF = pd.read_csv("Batsman.csv")
print(dF)
# Out:
#      RunsScored  BallsFaced  BattingPosition Dismissal  Inning   Opposition  \
# 0            12          22                2       LBW       1    Sri Lanka
# 1            37          67                2    Caught       2    Sri Lanka
# 2            25          38                1   Run out       1    Sri Lanka
# 3            54          66                1    Bowled       1    Sri Lanka
# 4            31          46                1       LBW       2    Sri Lanka
# ..          ...         ...              ...       ...     ...          ...
# 203         140         107                3   Stumped       2  West Indies
# 204         157         129                3        NO       1  West Indies
# 205         107         119                3    Bowled       2  West Indies
# 206          16          17                3    Caught       1  West Indies
# 207          33          29                3        NO       2  West Indies
#
#      Year
# 0    2008
# 1    2008
# 2    2008
# ...

# %%
plt.figure(figsize=(6,4))
plt.hist(df['RunsScored']) 
plt.show()

# %%
plt.figure(figsize=(5,4))
plt.hist(df['RunsScored'])
plt.title("Histogram RunsScored")       ##___Common Parameters to be included for all Visualization___##
plt.xlabel("RunsScored")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(5,4))
plt.hist(df['RunsScored'],bins=5,edgecolor='red',color='blue')
plt.title("Histogram RunsScored")
plt.xlabel("RunsScored")
plt.ylabel("Frequency")
plt.show()

# %%
df["Inning"]
# Out:
# 0      1
# 1      2
# 2      1
# 3      1
# 4      2
#       ..
# 203    2
# 204    1
# 205    2
# 206    1
# 207    2
# Name: Inning, Length: 208, dtype: int64

# %%
# 2) CountPlot


plt.figure(figsize=[5,5])
plt.title("Countplot for Dismissal")
plt.xlabel("Dismissal")
plt.ylabel("Frequence")
sns.countplot(x=df["Dismissal"],hue=df["Inning"],palette=["red","black"])
# Out:
# <Axes: title={'center': 'Countplot for Dismissal'}, xlabel='Dismissal', ylabel='Frequence'>

# %%
plt.figure(figsize = [5,5])
value_counts=df['Dismissal'].value_counts()
print(value_counts)
# Out:
# Dismissal
# Caught        121
# NO             37
# Bowled         21
# LBW            12
# Run out        12
# Stumped         4
# Hit wicket      1
# Name: count, dtype: int64

# %%
# 3) PieChart

plt.figure(figsize = [5,5])
value_counts=df['Dismissal'].value_counts()
print(value_counts)
# Out:
# Dismissal
# Caught        121
# NO             37
# Bowled         21
# LBW            12
# Run out        12
# Stumped         4
# Hit wicket      1
# Name: count, dtype: int64

# %%
plt.pie(value_counts,autopct="%0.2f%%",labels=value_counts.index)
plt.title("PieChart for Dismissal")
# Out:
# Text(0.5, 1.0, 'PieChart for Dismissal')

# %%
plt.figure(figsize = [5,5])
value_counts=df['Dismissal'].value_counts()
plt.pie(value_counts,autopct="%0.2f%%",labels=value_counts.index,explode=[0.20,0,0,0,0,0,0])
plt.title("PieChart for Dismissal")
# Out:
# Text(0.5, 1.0, 'PieChart for Dismissal')

# %% [markdown]
# # BI-VARIATE

# %%
# 2) ScatterPlot


sns.scatterplot(x=df['RunsScored'],y=df['BallsFaced'])
plt.show()

# %%
sns.scatterplot(x=df['RunsScored'],y=df['BallsFaced'],hue=df["Inning"])
plt.show()

# %%
# Boxplot

sns.boxplot(df['RunsScored'])
df.describe()
# Out:
#        RunsScored  BallsFaced  BattingPosition      Inning         Year
# count  208.000000  208.000000       208.000000  208.000000   208.000000
# mean    49.192308   52.961538         3.264423    1.567308  2013.240385
# std     43.797641   39.850548         0.781602    0.496644     2.750477
# min      0.000000    0.000000         1.000000    1.000000  2008.000000
# 25%     10.750000   18.000000         3.000000    1.000000  2011.000000
# 50%     35.000000   46.500000         3.000000    2.000000  2013.000000
# 75%     81.250000   83.250000         3.000000    2.000000  2015.000000
# max    183.000000  159.000000         7.000000    2.000000  2018.000000

# %%
sns.boxplot(x=df['RunsScored'],y=df['Dismissal'])
df.describe()
plt.show()

# %%
plt.figure(figsize = [5,5])
sns.boxplot(x=df['Inning'],y=df['RunsScored'],hue=df["Dismissal"])
df.describe()
# Out:
#        RunsScored  BallsFaced  BattingPosition      Inning         Year
# count  208.000000  208.000000       208.000000  208.000000   208.000000
# mean    49.192308   52.961538         3.264423    1.567308  2013.240385
# std     43.797641   39.850548         0.781602    0.496644     2.750477
# min      0.000000    0.000000         1.000000    1.000000  2008.000000
# 25%     10.750000   18.000000         3.000000    1.000000  2011.000000
# 50%     35.000000   46.500000         3.000000    2.000000  2013.000000
# 75%     81.250000   83.250000         3.000000    2.000000  2015.000000
# max    183.000000  159.000000         7.000000    2.000000  2018.000000

# %%
plt.figure(figsize = [5,5])
sns.boxplot(x=df['Inning'],y=df['RunsScored'],hue=df["Dismissal"],palette=["red","blue","green","pink","black","yellow","purple"])
df.describe()
# Out:
#        RunsScored  BallsFaced  BattingPosition      Inning         Year
# count  208.000000  208.000000       208.000000  208.000000   208.000000
# mean    49.192308   52.961538         3.264423    1.567308  2013.240385
# std     43.797641   39.850548         0.781602    0.496644     2.750477
# min      0.000000    0.000000         1.000000    1.000000  2008.000000
# 25%     10.750000   18.000000         3.000000    1.000000  2011.000000
# 50%     35.000000   46.500000         3.000000    2.000000  2013.000000
# 75%     81.250000   83.250000         3.000000    2.000000  2015.000000
# max    183.000000  159.000000         7.000000    2.000000  2018.000000

# %%
# Barplot

plt.figure(figsize = [5,5])
sns.barplot(x=df['Inning'],y=df['RunsScored'])
df.describe()
# Out:
#        RunsScored  BallsFaced  BattingPosition      Inning         Year
# count  208.000000  208.000000       208.000000  208.000000   208.000000
# mean    49.192308   52.961538         3.264423    1.567308  2013.240385
# std     43.797641   39.850548         0.781602    0.496644     2.750477
# min      0.000000    0.000000         1.000000    1.000000  2008.000000
# 25%     10.750000   18.000000         3.000000    1.000000  2011.000000
# 50%     35.000000   46.500000         3.000000    2.000000  2013.000000
# 75%     81.250000   83.250000         3.000000    2.000000  2015.000000
# max    183.000000  159.000000         7.000000    2.000000  2018.000000

# %%
plt.figure(figsize = [5,5])
sns.barplot(x=df['Inning'],y=df['RunsScored'],hue=df["Dismissal"])
df.describe()
# Out:
#        RunsScored  BallsFaced  BattingPosition      Inning         Year
# count  208.000000  208.000000       208.000000  208.000000   208.000000
# mean    49.192308   52.961538         3.264423    1.567308  2013.240385
# std     43.797641   39.850548         0.781602    0.496644     2.750477
# min      0.000000    0.000000         1.000000    1.000000  2008.000000
# 25%     10.750000   18.000000         3.000000    1.000000  2011.000000
# 50%     35.000000   46.500000         3.000000    2.000000  2013.000000
# 75%     81.250000   83.250000         3.000000    2.000000  2015.000000
# max    183.000000  159.000000         7.000000    2.000000  2018.000000

# %%
plt.figure(figsize = [5,5])
sns.barplot(x=df['Inning'],y=df['RunsScored'],hue=df["Dismissal"],palette=["red","blue","green","pink","black","yellow","purple"])
df.describe()
# Out:
#        RunsScored  BallsFaced  BattingPosition      Inning         Year
# count  208.000000  208.000000       208.000000  208.000000   208.000000
# mean    49.192308   52.961538         3.264423    1.567308  2013.240385
# std     43.797641   39.850548         0.781602    0.496644     2.750477
# min      0.000000    0.000000         1.000000    1.000000  2008.000000
# 25%     10.750000   18.000000         3.000000    1.000000  2011.000000
# 50%     35.000000   46.500000         3.000000    2.000000  2013.000000
# 75%     81.250000   83.250000         3.000000    2.000000  2015.000000
# max    183.000000  159.000000         7.000000    2.000000  2018.000000

# %%
plt.figure(figsize = [5,5])
sns.barplot(x=df['Inning'],y=df['RunsScored'],hue=df["Dismissal"],palette=["red","blue","green","pink","black","yellow","purple"],errorbar=(None))
df.describe()
# Out:
#        RunsScored  BallsFaced  BattingPosition      Inning         Year
# count  208.000000  208.000000       208.000000  208.000000   208.000000
# mean    49.192308   52.961538         3.264423    1.567308  2013.240385
# std     43.797641   39.850548         0.781602    0.496644     2.750477
# min      0.000000    0.000000         1.000000    1.000000  2008.000000
# 25%     10.750000   18.000000         3.000000    1.000000  2011.000000
# 50%     35.000000   46.500000         3.000000    2.000000  2013.000000
# 75%     81.250000   83.250000         3.000000    2.000000  2015.000000
# max    183.000000  159.000000         7.000000    2.000000  2018.000000

# %%
#  Lineplot


plt.figure(figsize=[5,5])
sns.lineplot(x=df["Year"],y=df["RunsScored"])
plt.title("Lineplot")
plt.xlabel("Year")
plt.ylabel("RunsScored")
plt.show()

# %%
plt.figure(figsize = [5,5])
sns.lineplot(x=df['Year'],y=df['RunsScored']) 
df.describe()
# Out:
#        RunsScored  BallsFaced  BattingPosition      Inning         Year
# count  208.000000  208.000000       208.000000  208.000000   208.000000
# mean    49.192308   52.961538         3.264423    1.567308  2013.240385
# std     43.797641   39.850548         0.781602    0.496644     2.750477
# min      0.000000    0.000000         1.000000    1.000000  2008.000000
# 25%     10.750000   18.000000         3.000000    1.000000  2011.000000
# 50%     35.000000   46.500000         3.000000    2.000000  2013.000000
# 75%     81.250000   83.250000         3.000000    2.000000  2015.000000
# max    183.000000  159.000000         7.000000    2.000000  2018.000000

# %%
plt.figure(figsize = [5,5])
sns.lineplot(x=df['Year'],y=df['RunsScored'],hue=df["Inning"])
df.describe()
# Out:
#        RunsScored  BallsFaced  BattingPosition      Inning         Year
# count  208.000000  208.000000       208.000000  208.000000   208.000000
# mean    49.192308   52.961538         3.264423    1.567308  2013.240385
# std     43.797641   39.850548         0.781602    0.496644     2.750477
# min      0.000000    0.000000         1.000000    1.000000  2008.000000
# 25%     10.750000   18.000000         3.000000    1.000000  2011.000000
# 50%     35.000000   46.500000         3.000000    2.000000  2013.000000
# 75%     81.250000   83.250000         3.000000    2.000000  2015.000000
# max    183.000000  159.000000         7.000000    2.000000  2018.000000

# %%
plt.figure(figsize = [5,5])
sns.lineplot(x=df['Year'],y=df['RunsScored'],hue=df["Inning"],palette=["black","yellow"])
df.describe()
# Out:
#        RunsScored  BallsFaced  BattingPosition      Inning         Year
# count  208.000000  208.000000       208.000000  208.000000   208.000000
# mean    49.192308   52.961538         3.264423    1.567308  2013.240385
# std     43.797641   39.850548         0.781602    0.496644     2.750477
# min      0.000000    0.000000         1.000000    1.000000  2008.000000
# 25%     10.750000   18.000000         3.000000    1.000000  2011.000000
# 50%     35.000000   46.500000         3.000000    2.000000  2013.000000
# 75%     81.250000   83.250000         3.000000    2.000000  2015.000000
# max    183.000000  159.000000         7.000000    2.000000  2018.000000

# %%
#  Violinplot


plt.figure(figsize=[5,5])
sns.violinplot(x=df["Year"],y=df["RunsScored"])
plt.title("Lineplot")
plt.xlabel("Year")
plt.ylabel("RunsScored")
plt.show()

# %%
plt.figure(figsize = [5,5])
sns.violinplot(x=df['Year'],y=df['RunsScored']) 
df.describe()
# Out:
#        RunsScored  BallsFaced  BattingPosition      Inning         Year
# count  208.000000  208.000000       208.000000  208.000000   208.000000
# mean    49.192308   52.961538         3.264423    1.567308  2013.240385
# std     43.797641   39.850548         0.781602    0.496644     2.750477
# min      0.000000    0.000000         1.000000    1.000000  2008.000000
# 25%     10.750000   18.000000         3.000000    1.000000  2011.000000
# 50%     35.000000   46.500000         3.000000    2.000000  2013.000000
# 75%     81.250000   83.250000         3.000000    2.000000  2015.000000
# max    183.000000  159.000000         7.000000    2.000000  2018.000000

# %%
plt.figure(figsize = [5,5])
sns.violinplot(x=df['Year'],y=df['RunsScored'],hue=df["Inning"])
df.describe()
# Out:
#        RunsScored  BallsFaced  BattingPosition      Inning         Year
# count  208.000000  208.000000       208.000000  208.000000   208.000000
# mean    49.192308   52.961538         3.264423    1.567308  2013.240385
# std     43.797641   39.850548         0.781602    0.496644     2.750477
# min      0.000000    0.000000         1.000000    1.000000  2008.000000
# 25%     10.750000   18.000000         3.000000    1.000000  2011.000000
# 50%     35.000000   46.500000         3.000000    2.000000  2013.000000
# 75%     81.250000   83.250000         3.000000    2.000000  2015.000000
# max    183.000000  159.000000         7.000000    2.000000  2018.000000

# %%
plt.figure(figsize = [5,5])
sns.violinplot(x=df['Year'],y=df['RunsScored'],hue=df["Inning"],palette=["black","yellow"])
df.describe()
# Out:
#        RunsScored  BallsFaced  BattingPosition      Inning         Year
# count  208.000000  208.000000       208.000000  208.000000   208.000000
# mean    49.192308   52.961538         3.264423    1.567308  2013.240385
# std     43.797641   39.850548         0.781602    0.496644     2.750477
# min      0.000000    0.000000         1.000000    1.000000  2008.000000
# 25%     10.750000   18.000000         3.000000    1.000000  2011.000000
# 50%     35.000000   46.500000         3.000000    2.000000  2013.000000
# 75%     81.250000   83.250000         3.000000    2.000000  2015.000000
# max    183.000000  159.000000         7.000000    2.000000  2018.000000

# %%
#  Stripplot


plt.figure(figsize=[5,5])
sns.stripplot(x=df["Year"],y=df["RunsScored"])
plt.title("Lineplot")
plt.xlabel("Year")
plt.ylabel("RunsScored")
plt.show()

# %%
plt.figure(figsize = [5,5])
sns.stripplot(x=df['Year'],y=df['RunsScored'],hue=df["Inning"])
df.describe()
# Out:
#        RunsScored  BallsFaced  BattingPosition      Inning         Year
# count  208.000000  208.000000       208.000000  208.000000   208.000000
# mean    49.192308   52.961538         3.264423    1.567308  2013.240385
# std     43.797641   39.850548         0.781602    0.496644     2.750477
# min      0.000000    0.000000         1.000000    1.000000  2008.000000
# 25%     10.750000   18.000000         3.000000    1.000000  2011.000000
# 50%     35.000000   46.500000         3.000000    2.000000  2013.000000
# 75%     81.250000   83.250000         3.000000    2.000000  2015.000000
# max    183.000000  159.000000         7.000000    2.000000  2018.000000

# %%
plt.figure(figsize = [5,5])
sns.stripplot(x=df['Year'],y=df['RunsScored'],hue=df["Inning"],palette=["black","yellow"])
df.describe()
# Out:
#        RunsScored  BallsFaced  BattingPosition      Inning         Year
# count  208.000000  208.000000       208.000000  208.000000   208.000000
# mean    49.192308   52.961538         3.264423    1.567308  2013.240385
# std     43.797641   39.850548         0.781602    0.496644     2.750477
# min      0.000000    0.000000         1.000000    1.000000  2008.000000
# 25%     10.750000   18.000000         3.000000    1.000000  2011.000000
# 50%     35.000000   46.500000         3.000000    2.000000  2013.000000
# 75%     81.250000   83.250000         3.000000    2.000000  2015.000000
# max    183.000000  159.000000         7.000000    2.000000  2018.000000

# %%
numerical_col=df.select_dtypes(include=['int64','float64'])
print(numerical_col)
# Out:
#      RunsScored  BallsFaced  BattingPosition  Inning  Year
# 0            12          22                2       1  2008
# 1            37          67                2       2  2008
# 2            25          38                1       1  2008
# 3            54          66                1       1  2008
# 4            31          46                1       2  2008
# ..          ...         ...              ...     ...   ...
# 203         140         107                3       2  2018
# 204         157         129                3       1  2018
# 205         107         119                3       2  2018
# 206          16          17                3       1  2018
# 207          33          29                3       2  2018
#
# [208 rows x 5 columns]

# %%
numerical_col=df.select_dtypes(include=['int64','float64'])
print(numerical_col.corr())
# Out:
#                  RunsScored  BallsFaced  BattingPosition    Inning      Year
# RunsScored         1.000000    0.958191        -0.106910  0.081576  0.202092
# BallsFaced         0.958191    1.000000        -0.143914  0.068477  0.148131
# BattingPosition   -0.106910   -0.143914         1.000000 -0.114519 -0.169035
# Inning             0.081576    0.068477        -0.114519  1.000000  0.002244
# Year               0.202092    0.148131        -0.169035  0.002244  1.000000

# %%
numerical_col=df.select_dtypes(include=['int64','float64'])
corr_matrix=numerical_col.corr()
print(numerical_col.corr())
# Out:
#                  RunsScored  BallsFaced  BattingPosition    Inning      Year
# RunsScored         1.000000    0.958191        -0.106910  0.081576  0.202092
# BallsFaced         0.958191    1.000000        -0.143914  0.068477  0.148131
# BattingPosition   -0.106910   -0.143914         1.000000 -0.114519 -0.169035
# Inning             0.081576    0.068477        -0.114519  1.000000  0.002244
# Year               0.202092    0.148131        -0.169035  0.002244  1.000000

# %%
#  Heatmap

sns.heatmap(corr_matrix)       # -----it can use only heatmap matrix (corr()) ----#
plt.show()

# %%
sns.heatmap(corr_matrix,annot=True)
plt.show()

# %%
#  Pairplot   

sns.pairplot(numerical_col)      #- ----dont use in matrix for pairplot (corr()) ----#
plt.show()
